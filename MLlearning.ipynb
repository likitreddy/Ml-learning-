# %% [markdown]
# <a href="https://colab.research.google.com/github/likitreddy/Ml-learning-/blob/main/MLlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install scikit-learn

# %%
import sklearn

# %%
from sklearn import datasets, model_selection, metrics, linear_model, preprocessing

# %%
from sklearn.datasets import load_iris
data = load_iris()
